# %% [markdown]
# <a href="https://colab.research.google.com/github/SomdeepAcharyya/NLP/blob/main/Word_Embeddings_Glove_and_Elmo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementation of Glove and ELMO word embedding models

# %% [markdown]
# ## Headers

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# !pip install gensim
import pandas as pd
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings
  
warnings.filterwarnings(action = 'ignore')

# %%
import gensim
from gensim.models import Word2Vec

# %%
# Tripadvisor Dataset

path = r'/content/drive/MyDrive/Per_CD_RS/tripadvisor_reviews.csv'
with open(path, encoding="utf-8", errors='ignore') as infile:
  tripadvisor = pd.read_csv(infile)

# %%
tripadvisor.columns
# Out:
# Index(['id', 'username', 'type', 'date', 'title', 'text', 'rating',
#        'helpfulness', 'total_points', 'taObject', 'taObjectUrl',
#        'taObjectCity', 'open', 'cons', 'extra', 'agree', 'neuro',
#        'processed_text', 'processed_title'],
#       dtype='object')

# %%
import numpy as np
lines = np.array(tripadvisor.text)
lines
# Out:
# array(['Decent Hotel next to station so good location for getting round Stockholm - room a little on the small size - due for a refurbishment - but was still comfortable - room was quiet.\n\nBreakfast Buffet good of a morning though not quite as good as the Readisson Waterfront round the corner.\n\nStayed on the 6th floor in a corner room near the lifts and staircase - could smell the chlorine coming from the pool in the basement! in the corrindor though not in the room.\n\nWould recommend it',
#        'Excellent Hotel - well situated for getting round stockholm - right by the station so easy access to the Arlanda Express for the airport.\n\nGreat Breakfast Buffet. Rooms overlooking waterfront have great views those at the back look directly into an office block! Free Internet Access!\n\nRooms very modern - beds very comfortable - highly recommended. Being staying here a couple of nights a week for the last 5 months or so.\n\nRestaurant of evening - limited menu but food is good.',
#        'Great Museum - abslutely worth making the time to visit - I spent just over an hour there - had to leave top catch a flight otherwise would have stayed longer.\n\nMust do Visit when in Stockholm',
#        ...,
#        'Friendly and helpful staff. They helped us choose dishes from the menu when our Dutch language skills ran out.\n\nExcellent food and a good atmosphere inside.\n\nWe only visited in the evenings, once for a drink and once for dinner. It was too windy for us to sit outside, but they have plenty of outside seating with wind-breaks if the weather is better.\n\nA really good place to watch the sun go down out at sea.',
#        'We stayed in the studio apartment, which comprises a bedroom, small kitchen and shower/WC room.\n\nThe accommodation was very comfortable and clean. The bed, in particular, was really comfortable.\n\nThe balcony faced inland so overlooked other buildings rather than the sea (but this is clear from the web site, so I am not complaining). The sun shone on it in the morning and throughout the day but not in the evening, when it could be a bit chilly, especially with the coastal wind.\n\nThe owner has car parking permits for guests that allow you to park on the street or in car parks in the surrounding area. There were always spaces in the street at the front of the apartment and I parked right in front of the hotel.\n\nThe staircase in the building is very narrow and steep, as is usual for this style of building. If you think this might give you a problem you can book ground floor rooms so you won??t have to use the stairs.\n\nMy only criticism is that we heard a lot of noise from other apartments in the building. This is probably to be expected in a narrow terraced building. We had noisy neighbours for the first couple of days of our stay and when they moved out and other people moved in we heard a lot less. I think this is probably more to do with inconsiderate neighbours than the apartment (the first neighbours seemed to be constantly on the move, banging around and slamming doors ?? we couldn??t work out what they were doing in a small studio apartment!).\n\nThere is a decent-sized supermarket immediately opposite the apartments which should provide all your grocery needs for your stay, without having to drive.\n\nWe found Zandvoort to be a good base. The station is about 5 minutes walk away with a half-hourly service to Amsterdam and Haarlem, with connections to other parts of the country. We found the service to be clean, reliable and we always got seats. Haarlem is definitely worth a visit ?? we enjoyed it far more than Amsterdam, which we were really disappointed with (and glad we hadn??t stayed there).\n\nThere are a number of bars & restaurants on the beach. Although these have extensive outdoor areas they all have an indoor area, so they are fine in the evenings even if it is a bit windy outdoors. They also serve good food. They are not what I expected when I read that there were ??beach bars??; they provide a decent option for dinner or a drink. The town seemed really quiet at night, although it does also have a number of bars and restaurants.\n\nIf we come back to this area we would almost certainly stay at the Welkom In.',
#        'The restaurant offers good quality food at prices that are lower than you would pay in one of the more central restaurants. It is about 10-15 minutes walk from the centre (Markt), near St Gilles church, but we visited as we were staying nearby.\n\nIt doesn??t look much from the outside, and you can??t really see inside before committing yourself and going in. Inside, it is an impressive room ?? high ceiling, large open fireplace (not lit when we visited in June!). However, it lacked atmosphere. To be fair, we visited on a Sunday evening and there were few other customers. The other groups all appeared to be locals and at times the owner seemed more interested in chatting with them than serving us.\nWhen the food came it was excellent and very well presented.\n\nI would give this place 5 stars for the quality of food but I have reduced the overall rating due to the lack of atmosphere.'],
#       dtype=object)

# %%
data = []

for i in range(len(tripadvisor)):
  x = tripadvisor.text[i]
  
  # iterate through each sentence in the file
  for i in sent_tokenize(x):
      temp = []
        
      # tokenize the sentence into words
      for j in word_tokenize(i):
          temp.append(j.lower())
  
  data.append(temp)

# %%
lines = list(tripadvisor.text)
word_tokens = data

# %%
from nltk.corpus import stopwords 
nltk.download('stopwords')
stop_words=stopwords.words('english') 
lines_without_stopwords=[] 
for line in lines: 
  stop_removed=[] 
for line in word_tokens:
  for word in line: 
    if word not in stop_words: 
      stop_removed.append(word) 
print(stop_removed)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['would', 'recommend', 'restaurant', 'evening', '-', 'limited', 'menu', 'food', 'good', '.', 'must', 'visit', 'stockholm', 'would', 'stay', '.', '&', 'acute', ';', 'speak', 'highly', 'restaurant', '-', 'visit', 'san', 'diego', 'love', 'steak', 'must', 'go', '.', 'stay', 'next', 'time', '&', 'acute', ';', 'san', 'diego', '&', 'acute', ';', 'pay', 'park', '$', '55', 'night', '-', 'block', 'away', 'get', 'day', 'pass', '$', '30', '!', 'would', 'stayed', 'longer', 'time', '-', 'plenty', 'different', 'things', 'around', 'area', '.', 'definitely', 'stay', 'early', 'morning', 'flight', '.', 'well', 'worth', 'staying', '&', 'acute', ';', 'mind', '30', 'min', 'journey', 'london', 'train', ',', 'also', 'night', 'bus', 'takes', '45', 'minutes', 'early', 'hours', 'train', 'stopped', '.', 'free', 'inter', 'net', 'slow', 'free', 'unlike', 'places', '!', 'stay', 'quite', 'often', 'far', 'holland', 'park', 'notting', 'hill', '.', 'impressed', 'waitress', 'either', '-', 'pointed', 'dirt', 'jug', '&', 'acute', ';', 'say', 'anything', 'walked', '.', 'make', 'sure', 'leave', 'room', 'dessert', 'must', '15-20', 'choose', '!', 'huge', 'selection', 'fresh', 'fish', 'prawn', 'starter', 'dishes', 'best', '!', 'service', 'however', 'excellent', 'although', '&', 'acute', ';', 'returning', 'time', 'soon', '!', 'comic', 'book', 'style', 'menu', 'also', 'awesome', '!', 'staff', 'friendly', '-', 'going', 'back', 'next', 'time', '&', 'acute', ';', 'london', ':', ')', 'would', 'definitely', 'stay', 'hotel', '.', 'hotels', 'also', 'offers', 'free', 'wifi', 'free', 'coffee/tea', 'cakes', 'afternoons', 'overall', 'great', 'hotel', '!', 'many', 'massages', 'say', 'hot', 'poultice', 'massage', 'best', 'far', '-', 'definitely', 'recommend', 'treatment', 'anyone', 'staying', 'hotel', '!', 'would', 'definitely', 'go', 'back', 'hotel', '.', 'also', 'lunch', 'one', 'days', 'food', 'fantastic', ',', 'place', 'always', 'busy', 'says', 'great', 'location', 'people', 'watch', '!', 'would', 'definitely', 'recommend', 'hotel', 'anyone', 'looking', 'stay', 'sorrento', 'easy', 'walk', 'everywhere', '(', 'plus', 'train', 'station', '5', 'minutes', 'away', ')', 'great', 'price', 'compared', 'hotels', 'main', 'part', 'sorrento', '.', 'opinion', 'magdalen', 'chapter', 'without', 'doubt', '5*', 'hotel', '.', '?', '101', '&', 'acute', ';', 'think', 'bad', 'london', 'prices', 'go', ',', 'however', 'hotel', 'bit', 'walk', 'nearest', 'tube', 'station', '.', 'pure', 'luxury', 'would', 'love', 'visit', ':', ')', 'staff', 'extremely', 'friendly', 'helpful', ',', 'plenty', 'places', 'near', 'evening', 'meal', 'public', 'transport', 'ruins', 'close', 'hotel', '.', 'would', 'definitely', 'go', 'back', '.', 'apart', 'amazing', 'time', ',', 'would', 'go', 'back', 'october', 'due', 'rainy', 'season', '!', 'helpful', 'reception', 'staff', '.', 'giving', 'restaurant', 'preference', 'hotel', 'guests', ',', 'emailing', 'situation', 'beforehand', ',', 'would', 'much', 'ask', '.', 'highly', 'recommended', '.', 'classy', 'experience', 'bartender', '/', 'food', 'server', 'lounge', ',', 'instead', 'attending', 'guests', 'spent', 'time', 'energy', 'loudly', 'constantly', 'hitting', 'group', 'giggling', 'girls', ',', 'including', 'trying', 'convince', 'least', 'hour', '``', 'pull', 'all-nighter', "''", 'shift', '.', 'bit', 'hard', 'find', 'maps', 'signage', ',', 'make', 'sure', 'get', 'proper', 'directions', 'beforehand', '.', 'service/hospitality', 'side', 'things', ',', 'team', 'bit', 'rough', 'gives', 'whole', 'place', 'feel', 'hostel', ',', 'transient', 'guests', 'basically', 'expected', 'help', '.', 'combination', 'clueless', 'service', 'bad', 'food', 'left', 'lot', 'desired', '.', 'decor', 'rooms', 'common', 'areas', 'bit', 'dated', 'caters', 'older', 'crowd', ',', 'add', 'homey', 'atmosphere', '.', 'decor', 'exuberant', 'maybe', 'everyone', '&', 'acute', ';', 'taste', ',', 'take', 'away', 'quality', 'hosts', 'location', '.', 'still', ',', 'would', 'definitely', 'come', 'back', 'durban', 'area', '.' ...

# %%
nltk.download('wordnet')
from nltk import WordNetLemmatizer  
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer() 
lines_with_lemmas=[] #stop words contain the set of stop words 
for line in lines: 
  lem_line=[] 
for word in stop_removed: 
  lem_line.append(wordnet_lemmatizer.lemmatize(word)) 
string='' 
new_lines=','.join([str(i) for i in lem_line])
print(lem_line)
print(new_lines)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Word2vec

# %%
# Word2zvec
model1 = gensim.models.Word2Vec(data, min_count = 1, size = 100, window = 5)    #CBOW
model2 = gensim.models.Word2Vec(data, min_count = 1, size = 100, window = 5, sg = 1)   #Skip grams

# %%
print(model1.similarity('fascinating', 'disappointing'))
print(model2.similarity('fascinating', 'disappointing'))
# Out:
# 0.84259117
# 0.8542597

# %% [markdown]
# # Glove

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
## download the word vectors

# %%
import gensim.downloader as api
glove_model = api.load('glove-wiki-gigaword-300')
# Out:
# [==================================================] 100.0% 376.1/376.1MB downloaded

# %%
## vector representation of a word

# %%
glove_model["beautiful"]

# %%
## word vectors understand the meanings of words

# %%
glove_model.most_similar("girl")

# %%
## queen - girl + boy = king

# %%
glove_model.most_similar(positive=['boy', 'queen'], negative=['girl'], topn=1)
# Out:
# [('king', 0.6770139336585999)]

# %%
vocab = ["boy", "girl", "man", "woman", "king", "queen", "banana", "apple", "mango", "fruit", "coconut", "orange"]
def tsne_plot(model):
  labels = []
  wordvecs = []
  for word in vocab:
        wordvecs.append(model[word])
        labels.append(word)
  tsne_model = TSNE(perplexity=3, n_components=2, init='pca', random_state=42)
  coordinates = tsne_model.fit_transform(wordvecs)
  x = []
  y = []
  for value in coordinates:
        x.append(value[0])
        y.append(value[1])
  plt.figure(figsize=(8,8))
  for i in range(len(x)):
            plt.scatter(x[i],y[i])
            plt.annotate(labels[i], xy=(x[i], y[i]), xytext=(2, 2), textcoords='offset points', ha='right', va='bottom')
  plt.show()
  
tsne_plot(glove_model)

# %% [markdown]
# # Elmo

# %%
# !pip install "tensorflow>=2.0.0"
# !pip install --upgrade tensorflow-hub

# %%
# import necessary libraries
import tensorflow_hub as hub
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
  
# Load pre trained ELMo model
elmo = hub.Module("https://tfhub.dev/google/elmo/3", trainable=True)
  
# create an instance of ELMo
embeddings = elmo(
    [
        "I love to watch TV",
        "I am wearing a wrist watch"
    ],
    signature="default",
    as_dict=True)["elmo"]
init = tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)

# %%
# Print word embeddings for word WATCH in given two sentences
print('Word embeddings for word WATCH in first sentence')
print(sess.run(embeddings[0][3]))
print('Word embeddings for word WATCH in second sentence')
print(sess.run(embeddings[1][5]))
# Out:
# Word embeddings for word WATCH in first sentence
# [ 0.14079645 -0.15788531 -0.00950466 ...  0.4300597  -0.52887094
#   0.06327899]
# Word embeddings for word WATCH in second sentence
# [-0.08213335  0.01050366 -0.01454147 ...  0.48705393 -0.54457957
#   0.5262399 ]

# %%
embeddings[0][3]
# Out:
# <tf.Tensor 'strided_slice_5:0' shape=(1024,) dtype=float32>
